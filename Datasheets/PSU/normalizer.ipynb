# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# %%
df = pd.read_csv(r'D:\Projects\0FYP\Datasheets\PSU\psu_v1.csv')
df.head()
# Out:
#                          name   price type  efficiency  wattage  modular
# 0              Corsair RM750e   99.99  ATX        87.0      750     10.0  \
# 1              Corsair RM850x  149.99  ATX        87.0      850     10.0
# 2             Corsair RM1000x  169.99  ATX        87.0     1000     10.0
# 3  Thermaltake Toughpower GX2   66.98  ATX        87.0      600      0.0
# 4              Corsair RM750x  119.99  ATX        87.0      750     10.0
#
#    color efficiency_type modularity
# 0  Black            gold       Full
# 1  Black            gold       Full
# 2  Black            gold       Full
# 3  Black            gold      False
# 4  Black            gold       Full

# %%
#'storage': {'capacity': 0.4, 'speed': 0.3, 'price_per_gb': 0.2, 'cache': 0.1},

# %%
df[['Watts']] = df[['wattage']]
#df['capacity_spec'] = df['capacity_spec'] / 1000
df
# Out:
#                             name   price type  efficiency  wattage  modular
# 0                 Corsair RM750e   99.99  ATX        87.0      750     10.0  \
# 1                 Corsair RM850x  149.99  ATX        87.0      850     10.0
# 2                Corsair RM1000x  169.99  ATX        87.0     1000     10.0
# 3     Thermaltake Toughpower GX2   66.98  ATX        87.0      600      0.0
# 4                 Corsair RM750x  119.99  ATX        87.0      750     10.0
# ...                          ...     ...  ...         ...      ...      ...
# 2518         Cougar COUGAR-SX850     NaN  ATX        85.0      850     10.0
# 2519                Apevia Astro     NaN  ATX         0.0      450      0.0
# 2520           Silverstone NJ600     NaN  ATX        94.0      600     10.0
# 2521         Mushkin MKNPSJL1000     NaN  ATX        87.0     1000      0.0
# 2522             Ultra U12-42466     NaN  ATX        82.0      650      6.0
#
#        color efficiency_type modularity  Watts
# 0      Black            gold       Full    750
# 1      Black            gold       Full    850
# 2      Black            gold       Full   1000
# 3      Black            gold      False    600
# 4      Black            gold       Full    750
# ...      ...             ...        ...    ...
# 2518     NaN          silver       Full    850
# 2519   Black           white      False    450
# 2520  Silver        titanium       Full    600
# 2521     NaN            gold      False   1000
# 2522     NaN          bronze       Semi    650
#
# [2523 rows x 10 columns]

# %%
#'gpu': {'memory': 2.2, 'memory_ver': 1, 'g3dmark': 1.2, 'api_score': 1.2, 'blender_score': 1.2, 'fps_score': 1.2},
scaler_min_max = MinMaxScaler()
df[['efficiency', 'wattage', 'modular']] = scaler_min_max.fit_transform(df[['efficiency', 'wattage', 'modular']])
df
# Out:
#                             name   price type  efficiency   wattage  modular
# 0                 Corsair RM750e   99.99  ATX    0.925532  0.297297      1.0  \
# 1                 Corsair RM850x  149.99  ATX    0.925532  0.351351      1.0
# 2                Corsair RM1000x  169.99  ATX    0.925532  0.432432      1.0
# 3     Thermaltake Toughpower GX2   66.98  ATX    0.925532  0.216216      0.0
# 4                 Corsair RM750x  119.99  ATX    0.925532  0.297297      1.0
# ...                          ...     ...  ...         ...       ...      ...
# 2518         Cougar COUGAR-SX850     NaN  ATX    0.904255  0.351351      1.0
# 2519                Apevia Astro     NaN  ATX    0.000000  0.135135      0.0
# 2520           Silverstone NJ600     NaN  ATX    1.000000  0.216216      1.0
# 2521         Mushkin MKNPSJL1000     NaN  ATX    0.925532  0.432432      0.0
# 2522             Ultra U12-42466     NaN  ATX    0.872340  0.243243      0.6
#
#        color efficiency_type modularity  Watts
# 0      Black            gold       Full    750
# 1      Black            gold       Full    850
# 2      Black            gold       Full   1000
# 3      Black            gold      False    600
# 4      Black            gold       Full    750
# ...      ...             ...        ...    ...
# 2518     NaN          silver       Full    850
# 2519   Black           white      False    450
# 2520  Silver        titanium       Full    600
# 2521     NaN            gold      False   1000
# 2522     NaN          bronze       Semi    650
#
# [2523 rows x 10 columns]

# %%
#'gpu': {'memory': 2.2, 'memory_ver': 1, 'g3dmark': 1.2, 'api_score': 1.2, 'blender_score': 1.2, 'fps_score': 1.2},

# %%
df['price_per_gb'] = 1 - df['price_per_gb']
df
# Out:
#                            name  price  capacity  price_per_gb  type
# 0          Samsung 970 Evo Plus  54.99  0.045107      0.990263   SSD  \
# 1               Samsung 980 Pro  99.99  0.090578      0.991370   SSD
# 2               Samsung 980 Pro  59.99  0.045107      0.989157   SSD
# 3                  Kingston NV2  42.99  0.045107      0.992919   SSD
# 4     Seagate Barracuda Compute  55.00  0.090578      0.996238  7200
# ...                         ...    ...       ...           ...   ...
# 4897             Netac NV7000-t    NaN  0.045107           NaN   SSD
# 4898         Nextorage G-Series    NaN  0.045107           NaN   SSD
# 4899           Seagate Exos X22    NaN  0.909058           NaN  7200
# 4900           Seagate Exos X22    NaN  0.909058           NaN  7200
# 4901           Seagate Exos X22    NaN  1.000000           NaN  7200
#
#          cache form_factor        interface     speed  capacity_spec
# 0     0.007812         M.2  M.2 PCIe 3.0 X4  0.488304            1.0  \
# 1     0.015625         M.2  M.2 PCIe 4.0 X4  1.000000            2.0
# 2     0.007812         M.2  M.2 PCIe 4.0 X4  1.000000            1.0
# 3     0.000000         M.2  M.2 PCIe 4.0 X4  1.000000            1.0
# 4     0.001953         3.5    SATA 6.0 Gb/s  0.000000            2.0
# ...        ...         ...              ...       ...            ...
# 4897  0.000000         M.2  M.2 PCIe 4.0 X4  1.000000            1.0
# 4898  0.000000         M.2  M.2 PCIe 4.0 X4  1.000000            1.0
# 4899  0.003906         3.5    SATA 6.0 Gb/s  0.000000           20.0
# 4900  0.003906         3.5    SATA 6.0 Gb/s  0.000000           20.0
# 4901  0.003906         3.5    SATA 6.0 Gb/s  0.000000           22.0
#
#       cache_spec  speed_spec
# 0           1024        3500
# 1           2048        7000
# 2           1024        7000
# 3              0        7000
# 4            256         160
# ...          ...         ...
# 4897           0        7000
# 4898           0        7000
# 4899         512         160
# 4900         512         160
# 4901         512         160
#
# [4902 rows x 12 columns]

# %%
df['type'] = df['type'].str.replace('7200', 'HDD')
df['type'] = df['type'].str.replace('5400', 'HDD')
df['type'] = df['type'].str.replace('5900', 'HDD')
df['type'] = df['type'].str.replace('10000', 'HDD')
df['type'] = df['type'].str.replace('5700', 'HDD')
df['type'] = df['type'].str.replace('5640', 'HDD')
df['type'] = df['type'].str.replace('5000', 'HDD')
df['type'] = df['type'].str.replace('5200', 'HDD')
df['type'] = df['type'].str.replace('5760', 'HDD')
df['type'] = df['type'].str.replace('5940', 'HDD')
df
# Out:
#                            name  price  capacity  price_per_gb type     cache
# 0          Samsung 970 Evo Plus  54.99  0.045107      0.990263  SSD  0.007812  \
# 1               Samsung 980 Pro  99.99  0.090578      0.991370  SSD  0.015625
# 2               Samsung 980 Pro  59.99  0.045107      0.989157  SSD  0.007812
# 3                  Kingston NV2  42.99  0.045107      0.992919  SSD  0.000000
# 4     Seagate Barracuda Compute  55.00  0.090578      0.996238  HDD  0.001953
# ...                         ...    ...       ...           ...  ...       ...
# 4897             Netac NV7000-t    NaN  0.045107           NaN  SSD  0.000000
# 4898         Nextorage G-Series    NaN  0.045107           NaN  SSD  0.000000
# 4899           Seagate Exos X22    NaN  0.909058           NaN  HDD  0.003906
# 4900           Seagate Exos X22    NaN  0.909058           NaN  HDD  0.003906
# 4901           Seagate Exos X22    NaN  1.000000           NaN  HDD  0.003906
#
#      form_factor        interface     speed  capacity_spec  cache_spec
# 0            M.2  M.2 PCIe 3.0 X4  0.488304            1.0        1024  \
# 1            M.2  M.2 PCIe 4.0 X4  1.000000            2.0        2048
# 2            M.2  M.2 PCIe 4.0 X4  1.000000            1.0        1024
# 3            M.2  M.2 PCIe 4.0 X4  1.000000            1.0           0
# 4            3.5    SATA 6.0 Gb/s  0.000000            2.0         256
# ...          ...              ...       ...            ...         ...
# 4897         M.2  M.2 PCIe 4.0 X4  1.000000            1.0           0
# 4898         M.2  M.2 PCIe 4.0 X4  1.000000            1.0           0
# 4899         3.5    SATA 6.0 Gb/s  0.000000           20.0         512
# 4900         3.5    SATA 6.0 Gb/s  0.000000           20.0         512
# 4901         3.5    SATA 6.0 Gb/s  0.000000           22.0         512
#
#       speed_spec
# 0           3500
# 1           7000
# 2           7000
# 3           7000
# 4            160
# ...          ...
# 4897        7000
# 4898        7000
# 4899         160
# 4900         160
# 4901         160
#
# [4902 rows x 12 columns]

# %%
df.to_csv('psu_final.csv', index=False)
