# %%
import pandas as pd
import pickle
import numpy as np

# %%
base = pd.read_csv(r'D:\Projects\0FYP\Datasheets\GPU\gpu_base_main.csv')
base
# Out:
#                  chipset  core_clock  boost_clock  memory_clock  memory
# 0       GeForce RTX 3060        1320         1777          1875     8.0  \
# 1    GeForce RTX 4070 Ti        2310         2640          1313    12.0
# 2       GeForce RTX 4070        1920         2490          1313    12.0
# 3       GeForce RTX 4090        2235         2640          1313    24.0
# 4         Radeon RX 6600        1626         1626          1750     8.0
# ..                   ...         ...          ...           ...     ...
# 433        FirePro V8750         750          750           900     2.0
# 434        FirePro S9000         900          900          1375     6.0
# 435       FirePro S10000         825          825          1250     3.0
# 436        Radeon R7 265         900          925          1400     2.0
# 437   GeForce GTX 780 Ti         875         1150          1753     3.0
#
#      memory_ver  bus_width  shaders  TMUs  ROPs          PCIe  TDP rec_psu
# 0             6        128     3584   112    48  PCIe 4.0 x16  170   450 W  \
# 1             6        192     7680   240    80  PCIe 4.0 x16  285   600 W
# 2             6        192     5888   184    64  PCIe 4.0 x16  200   550 W
# 3             6        384    16384   512   176  PCIe 4.0 x16  450   850 W
# 4             6        128     1792   112    64   PCIe 4.0 x8  132   300 W
# ..          ...        ...      ...   ...   ...           ...  ...     ...
# 433           5        256      800    40    16  PCIe 2.0 x16  151   450 W
# 434           5        384     1792   112    32  PCIe 3.0 x16  225   550 W
# 435           5        384     1792   112    32  PCIe 3.0 x16  375   750 W
# 436           5        256     1024    64    32  PCIe 3.0 x16  150   450 W
# 437           5        384     2880   240    48  PCIe 3.0 x16  250   600 W
#
#                                             detail_URL
# 0    https://www.techpowerup.com/gpu-specs/geforce-...
# 1    https://www.techpowerup.com/gpu-specs/geforce-...
# 2    https://www.techpowerup.com/gpu-specs/geforce-...
# 3    https://www.techpowerup.com/gpu-specs/geforce-...
# 4    https://www.techpowerup.com/gpu-specs/radeon-r...
# ..                                                 ...
# 433  https://www.techpowerup.com/gpu-specs/firepro-...
# 434  https://www.techpowerup.com/gpu-specs/firepro-...
# 435  https://www.techpowerup.com/gpu-specs/firepro-...
# 436  https://www.techpowerup.com/gpu-specs/radeon-r...
# 437  https://www.techpowerup.com/gpu-specs/geforce-...
#
# [438 rows x 14 columns]

# %%
base_stripped = base.drop_duplicates(subset=['chipset', 'memory'])
base_stripped
# Out:
#                  chipset  core_clock  boost_clock  memory_clock  memory
# 0       GeForce RTX 3060        1320         1777          1875     8.0  \
# 1    GeForce RTX 4070 Ti        2310         2640          1313    12.0
# 2       GeForce RTX 4070        1920         2490          1313    12.0
# 3       GeForce RTX 4090        2235         2640          1313    24.0
# 4         Radeon RX 6600        1626         1626          1750     8.0
# ..                   ...         ...          ...           ...     ...
# 430        FirePro V9800         850          850          1150     4.0
# 431        Radeon R7 260        1000         1000          1500     2.0
# 433        FirePro V8750         750          750           900     2.0
# 434        FirePro S9000         900          900          1375     6.0
# 435       FirePro S10000         825          825          1250     3.0
#
#      memory_ver  bus_width  shaders  TMUs  ROPs          PCIe  TDP rec_psu
# 0             6        128     3584   112    48  PCIe 4.0 x16  170   450 W  \
# 1             6        192     7680   240    80  PCIe 4.0 x16  285   600 W
# 2             6        192     5888   184    64  PCIe 4.0 x16  200   550 W
# 3             6        384    16384   512   176  PCIe 4.0 x16  450   850 W
# 4             6        128     1792   112    64   PCIe 4.0 x8  132   300 W
# ..          ...        ...      ...   ...   ...           ...  ...     ...
# 430           5        256     1600    80    32  PCIe 2.0 x16  250   600 W
# 431           5        128      768    48    16  PCIe 3.0 x16   95   250 W
# 433           5        256      800    40    16  PCIe 2.0 x16  151   450 W
# 434           5        384     1792   112    32  PCIe 3.0 x16  225   550 W
# 435           5        384     1792   112    32  PCIe 3.0 x16  375   750 W
#
#                                             detail_URL
# 0    https://www.techpowerup.com/gpu-specs/geforce-...
# 1    https://www.techpowerup.com/gpu-specs/geforce-...
# 2    https://www.techpowerup.com/gpu-specs/geforce-...
# 3    https://www.techpowerup.com/gpu-specs/geforce-...
# 4    https://www.techpowerup.com/gpu-specs/radeon-r...
# ..                                                 ...
# 430  https://www.techpowerup.com/gpu-specs/firepro-...
# 431  https://www.techpowerup.com/gpu-specs/radeon-r...
# 433  https://www.techpowerup.com/gpu-specs/firepro-...
# 434  https://www.techpowerup.com/gpu-specs/firepro-...
# 435  https://www.techpowerup.com/gpu-specs/firepro-...
#
# [324 rows x 14 columns]

# %%
base_stripped.to_csv('gpu_base.csv', index=False)

# %%
cpu_pass_LM = pd.read_csv('cpu_pass_LM.csv')
cpu_pass_LM
# Out:
#                      name   price  core_count  core_clock  boost_clock  tdp
# 0       AMD Ryzen 5 5600X  168.99           6         3.7          4.6   65  \
# 1       AMD Ryzen 7 5800X  228.72           8         3.8          4.7  105
# 2    Intel Core i7-13700K  381.99          16         3.4          5.4  125
# 3    Intel Core i9-13900K  568.99          24         3.0          5.8  125
# 4     AMD Ryzen 7 7800X3D  439.00           8         4.2          5.0  120
# ..                    ...     ...         ...         ...          ...  ...
# 889           AMD FX-4200     NaN           4         3.3          3.3  125
# 890           AMD FX-6130     NaN           6         3.6          3.9  125
# 891      AMD Pro A6-7400B     NaN           2         3.5          3.9   65
# 892     AMD Athlon X2 350     NaN           2         3.5          3.9   65
# 893  AMD Phenom II X4 B99     NaN           4         3.3          3.3   95
#
#                    graphics    smt       codename       socket lithography
# 0                       NaN   True        Vermeer   Socket AM4        7 nm  \
# 1                       NaN   True        Vermeer   Socket AM4        7 nm
# 2    Intel UHD Graphics 770   True  Raptor Lake-S  Socket 1700       10 nm
# 3    Intel UHD Graphics 770   True  Raptor Lake-S  Socket 1700       10 nm
# 4                    Radeon   True        Raphael   Socket AM5        5 nm
# ..                      ...    ...            ...          ...         ...
# 889                     NaN  False            NaN          NaN         NaN
# 890                     NaN  False        Zambezi  Socket AM3+       32 nm
# 891      Radeon R5 (on die)  False            NaN          NaN         NaN
# 892                     NaN  False       Brisbane   Socket AM2       65 nm
# 893                     NaN  False            NaN          NaN         NaN
#
#      cache supported_mem                                  supported_chipset
# 0    32 MB          DDR4    AMD 300 Series*, AMD 400 Series, AMD 500 Series  \
# 1    32 MB          DDR4    AMD 300 Series*, AMD 400 Series, AMD 500 Series
# 2    30 MB    DDR4, DDR5  H610, B660, H670, Q670, Z690, W680, B760, H770...
# 3    36 MB    DDR4, DDR5  H610, B660, H670, Q670, Z690, W680, B760, H770...
# 4    96 MB          DDR5                     X670E, X670, B650E, B650, A620
# ..     ...           ...                                                ...
# 889    NaN           NaN                                                NaN
# 890   8 MB          DDR3                                                NaN
# 891    NaN           NaN                                                NaN
# 892    NaN       unknown                                                NaN
# 893    NaN           NaN                                                NaN
#
#        release_date  pmprice  cpuMark  threadMark category
# 0     Nov 5th, 2020   216.99  22088.0      3377.0  Desktop
# 1     Nov 5th, 2020   333.99  28368.0      3485.0  Desktop
# 2    Sep 27th, 2022      NaN      NaN         NaN      NaN
# 3    Sep 27th, 2022      NaN      NaN         NaN      NaN
# 4     Jan 4th, 2023      NaN      NaN         NaN      NaN
# ..              ...      ...      ...         ...      ...
# 889             NaN      NaN      NaN         NaN      NaN
# 890  Oct 23rd, 2012      NaN      NaN         NaN      NaN
# 891             NaN      NaN      NaN         NaN      NaN
# 892   Oct 8th, 2007      NaN      NaN         NaN      NaN
# 893             NaN      NaN   2536.0      1377.0  Unknown
#
# [894 rows x 19 columns]

# %%
cpu_pass_LM['cache'] = cpu_pass_LM['cache'].str.replace(' MB', '')
cpu_pass_LM['lithography'] = cpu_pass_LM['lithography'].str.replace(' nm', '')

# %%
extras_cpu_pass = cpu_pass_LM.dropna(subset=['cache'])

# %%
with open('PDpassmark.pkl', 'rb') as file:
    model = pickle.load(file)

input_columns = ['core_count', 'boost_clock', 'tdp', 'smt', 'lithography']

df_new = extras_cpu_pass
for index, row in df_new.iterrows():
    if np.isnan(row['cpuMark']):
        X_pred = row[input_columns].values.reshape(1, -1)
        y_pred = model.predict(X_pred)      # making the prediction
        df_new.at[index, 'cpuMark'] = int(y_pred)
        df_new.at[index, 'passmarkPred'] = 'TRUE'
    else:
        df_new.at[index, 'passmarkPred'] = 'FALSE'
# Out:
# C:\Users\ZyroAki\AppData\Local\Temp\ipykernel_52772\2035959269.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.at[index, 'passmarkPred'] = 'FALSE'
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(

# %%
df_new
# Out:
#                         name   price  core_count  core_clock  boost_clock
# 0          AMD Ryzen 5 5600X  168.99           6         3.7          4.6  \
# 1          AMD Ryzen 7 5800X  228.72           8         3.8          4.7
# 2       Intel Core i7-13700K  381.99          16         3.4          5.4
# 3       Intel Core i9-13900K  568.99          24         3.0          5.8
# 4        AMD Ryzen 7 7800X3D  439.00           8         4.2          5.0
# ..                       ...     ...         ...         ...          ...
# 875    AMD Phenom II X4 905e     NaN           4         2.5          2.5
# 880       Intel Core i5-655K     NaN           2         3.2          3.2
# 883  AMD Phenom II X3 715 BE     NaN           3         2.8          2.8
# 884     AMD Phenom II X4 970     NaN           4         3.5          3.5
# 890              AMD FX-6130     NaN           6         3.6          3.9
#
#      tdp                graphics    smt       codename       socket
# 0     65                     NaN   True        Vermeer   Socket AM4  \
# 1    105                     NaN   True        Vermeer   Socket AM4
# 2    125  Intel UHD Graphics 770   True  Raptor Lake-S  Socket 1700
# 3    125  Intel UHD Graphics 770   True  Raptor Lake-S  Socket 1700
# 4    120                  Radeon   True        Raphael   Socket AM5
# ..   ...                     ...    ...            ...          ...
# 875   65                     NaN  False          Deneb   Socket AM3
# 880   73       Intel HD Graphics   True      Clarkdale  Socket 1156
# 883   95                     NaN  False           Heka  Socket AM2+
# 884  125                     NaN  False          Zosma   Socket AM3
# 890  125                     NaN  False        Zambezi  Socket AM3+
#
#     lithography cache supported_mem
# 0             7    32          DDR4  \
# 1             7    32          DDR4
# 2            10    30    DDR4, DDR5
# 3            10    36    DDR4, DDR5
# 4             5    96          DDR5
# ..          ...   ...           ...
# 875          45     6          DDR3
# 880          32     4          DDR3
# 883          45     6    DDR2, DDR3
# 884          45     6    DDR2, DDR3
# 890          32     8          DDR3
#
#                                      supported_chipset    release_date
# 0      AMD 300 Series*, AMD 400 Series, AMD 500 Series   Nov 5th, 2020  \
# 1      AMD 300 Series*, AMD 400 Series, AMD 500 Series   Nov 5th, 2020
# 2    H610, B660, H670, Q670, Z690, W680, B760, H770...  Sep 27th, 2022
# 3    H610, B660, H670, Q670, Z690, W680, B760, H770...  Sep 27th, 2022
# 4                       X670E, X670, B650E, B650, A620   Jan 4th, 2023
# ..                                                 ...             ...
# 875  AMD 700 Series, AMD 800 Series, AMD 900 Series...   Jun 2nd, 2009
# 880                                      H55, H57, P55  May 30th, 2010
# 883  AMD 700 Series, AMD 800 Series, AMD 900 Series...   Oct 1st, 2010
# 884  AMD 700 Series, AMD 800 Series, AMD 900 Series...   Oct 1st, 2010
# 890                                                NaN  Oct 23rd, 2012
#
#      pmprice  cpuMark  threadMark category passmarkPred
# 0     216.99  22088.0      3377.0  Desktop        FALSE
# 1     333.99  28368.0      3485.0  Desktop        FALSE
# 2        NaN  42307.0         NaN      NaN         TRUE
# 3        NaN  43348.0         NaN      NaN         TRUE
# 4        NaN  26121.0         NaN      NaN         TRUE
# ..       ...      ...         ...      ...          ...
# 875    53.99   1895.0      1029.0  Desktop        FALSE
# 880    77.99   2017.0      1446.0  Desktop        FALSE
# 883      NaN    968.0         NaN      NaN         TRUE
# 884    59.88   2644.0      1412.0  Unknown        FALSE
# 890      NaN   7189.0         NaN      NaN         TRUE
#
# [632 rows x 20 columns]

# %%
df_new.to_csv('cpu_pass_impute.csv', index=False)
