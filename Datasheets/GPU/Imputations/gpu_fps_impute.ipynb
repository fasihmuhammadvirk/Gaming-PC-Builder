# %%
import pandas as pd
import pickle
import numpy as np

# %%
gpu_fps_LM = pd.read_csv(r'D:\Projects\0FYP\Datasheets\GPU\Left Mergers\base_fps_LM.csv')
gpu_fps_LM
# Out:
#                  chipset  core_clock  boost_clock  memory_clock  memory
# 0       GeForce RTX 3060        1320         1777          1875     8.0  \
# 1    GeForce RTX 4070 Ti        2310         2640          1313    12.0
# 2       GeForce RTX 4070        1920         2490          1313    12.0
# 3       GeForce RTX 4090        2235         2640          1313    24.0
# 4         Radeon RX 6600        1626         1626          1750     8.0
# ..                   ...         ...          ...           ...     ...
# 319        FirePro V9800         850          850          1150     4.0
# 320        Radeon R7 260        1000         1000          1500     2.0
# 321        FirePro V8750         750          750           900     2.0
# 322        FirePro S9000         900          900          1375     6.0
# 323       FirePro S10000         825          825          1250     3.0
#
#      memory_ver  bus_width  shaders  TMUs  ROPs          PCIe  TDP rec_psu
# ...

# %%
with open('fps_predictor.pkl', 'rb') as file:
    model = pickle.load(file)

input_columns = ['boost_clock', 'memory_ver', 'bus_width', 'shaders', 'TMUs', 'ROPs']

df_new = gpu_fps_LM
for index, row in df_new.iterrows():
    if np.isnan(row['overall FPS performance']):
        X_pred = row[input_columns].values.reshape(1, -1)
        y_pred = model.predict(X_pred)      # making the prediction
        df_new.at[index, 'overall FPS performance'] = float(y_pred)
        #df_new.at[index, 'G2Dmark'] = float(y_pred[0][1])
        #df_new.at[index, 'passmarkPred'] = 'TRUE'
    #else:
        #df_new.at[index, 'passmarkPred'] = 'FALSE'
# Out:
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\ZyroAki\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# ...

# %%
df_new
# Out:
#                  chipset  core_clock  boost_clock  memory_clock  memory
# 0       GeForce RTX 3060        1320         1777          1875     8.0  \
# 1    GeForce RTX 4070 Ti        2310         2640          1313    12.0
# 2       GeForce RTX 4070        1920         2490          1313    12.0
# 3       GeForce RTX 4090        2235         2640          1313    24.0
# 4         Radeon RX 6600        1626         1626          1750     8.0
# ..                   ...         ...          ...           ...     ...
# 319        FirePro V9800         850          850          1150     4.0
# 320        Radeon R7 260        1000         1000          1500     2.0
# 321        FirePro V8750         750          750           900     2.0
# 322        FirePro S9000         900          900          1375     6.0
# 323       FirePro S10000         825          825          1250     3.0
#
#      memory_ver  bus_width  shaders  TMUs  ROPs          PCIe  TDP rec_psu
# ...

# %%
df_new.to_csv('gpu_fps_impute.csv', index=False)
