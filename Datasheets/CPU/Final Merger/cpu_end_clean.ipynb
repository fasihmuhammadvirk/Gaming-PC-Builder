# %%
import pandas as pd

# %%
df = pd.read_csv('finalCPUlist.csv')
df.head(3)
# Out:
#    Unnamed: 0                  name   price  core_count  core_clock
# 0           1     AMD Ryzen 5 5600X  168.99           6         3.7  \
# 1           2     AMD Ryzen 7 5800X  228.72           8         3.8
# 2           3  Intel Core i7-13700K  381.99          16         3.4
#
#    boost_clock  tdp                graphics   smt       codename  ...
# 0          4.6   65                     NaN  True        Vermeer  ...  \
# 1          4.7  105                     NaN  True        Vermeer  ...
# 2          5.4  125  Intel UHD Graphics 770  True  Raptor Lake-S  ...
#
#   supported_mem                                  supported_chipset
# 0          DDR4     A320, B350, X370, B450, X470, A520, B550, X570  \
# 1          DDR4     A320, B350, X370, B450, X470, A520, B550, X570
# 2    DDR4, DDR5  H610, B660, H670, Q670, Z690, W680, B760, H770...
#
#      release_date  passmark category passmarkPred  cinebench cinePred
# ...

# %%
df = df.rename(columns={'Unnamed: 0': 'index'})
df.head(3)
# Out:
#    index                  name   price  core_count  core_clock  boost_clock
# 0      1     AMD Ryzen 5 5600X  168.99           6         3.7          4.6  \
# 1      2     AMD Ryzen 7 5800X  228.72           8         3.8          4.7
# 2      3  Intel Core i7-13700K  381.99          16         3.4          5.4
#
#    tdp                graphics   smt       codename  ... supported_mem
# 0   65                     NaN  True        Vermeer  ...          DDR4  \
# 1  105                     NaN  True        Vermeer  ...          DDR4
# 2  125  Intel UHD Graphics 770  True  Raptor Lake-S  ...    DDR4, DDR5
#
#                                    supported_chipset    release_date
# 0     A320, B350, X370, B450, X470, A520, B550, X570   Nov 5th, 2020  \
# 1     A320, B350, X370, B450, X470, A520, B550, X570   Nov 5th, 2020
# 2  H610, B660, H670, Q670, Z690, W680, B760, H770...  Sep 27th, 2022
#
#    passmark category passmarkPred  cinebench cinePred   blender  blenderPred
# ...

# %%
df['socket'] = df['socket'].str.replace('Socket ', '')

# %%
df.to_csv('CPU.csv', index=False)
